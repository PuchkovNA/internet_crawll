# %%
import requests
from lxml import html

# %%
headers={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/108.0.0.0 Safari/537.36"}
list_news=[]
for i in range(10):
    req=requests.get("https://lenta.ru/parts/news/"+str(i)+"/", headers=headers)
    list_news.append(html.fromstring(req.text))

# %%
news=[]
for  i, one_page in enumerate(list_news):
    for j, item in enumerate(one_page.xpath('//body//ul[1]/li[@class="parts-page__item"]')):
            news.append([ item.xpath('a[@rel="noreferrer"]/@href')[0]  if item.xpath('a[@rel="noreferrer"]/@href') else "https://lenta.ru"+item.xpath('a/@href')[0], 
            item.xpath('a/h3[@class="card-full-news__title"]/text()')[0],
            item.xpath('a/div[@class="card-full-news__info"]/time/text()')[0],
            (item.xpath('a/div[@class="card-full-news__info"]/svg/use/@*')+item.xpath('a/div[@class="card-full-news__info"]/span/text()'))[0].replace('#ui-label_','')])

# %%
news[:][:]
# Out:
# [['https://lenta.ru/news/2022/12/18/robert/',
#   'Евросоюз обсудит снизить потолок цен на газ',
#   '23:07',
#   'Мир'],
#  ['https://lenta.ru/news/2022/12/18/putin_argentina/',
#   'Путин поздравил президента Аргентины с победой сборной на ЧМ',
#   '23:01',
#   'Россия'],
#  ['https://lenta.ru/news/2022/12/18/norway/',
#   'Стало известно об отказах Норвегии в выдаче виз россиянам',
#   '22:56',
#   'Путешествия'],
#  ['https://lenta.ru/news/2022/12/18/proizvol/',
#   'Бывший боец ВСУ рассказал о коррупции и произволе украинских командиров',
#   '22:49',
#   'Бывший СССР'],
#  ['https://lenta.ru/news/2022/12/18/neck/',
#   'Российский хоккеист госпитализирован после попадания коньком в шею',
#   '22:45',
#   '#ui-play'],
#  ['https://moslenta.ru/news/lyudi/vrednaya-novogodnyaya-tradiciya-18-12-2022.htm/',
#   'Доктор Долгов определил самую вредную новогоднюю традицию',
#   '22:31',
#   'moslenta'],
# ...
